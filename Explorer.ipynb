# %% [markdown]
# # Explorer
# ## pyLASCA
#
# (c) Sebastian Malkusch 2019

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataframe
# needs to be event driven

# %%
fileName = "/home/malkusch/PowerFolders/pharmacology/Daten/ristow/dataframe.csv"
df = pd.read_csv(fileName)
df
# Out:
#      thr      area      radius    perimeter   cntArea   cntRadius  \
# 0      1  218729.0  263.862849  2158.416301  218685.0  263.836308
# 1      2  218069.5  263.464756  2157.144223  218035.5  263.444216
# 2      3  217577.0  263.167076  2154.073156  217547.0  263.148933
# 3      4  217165.5  262.918097  2152.658942  217141.5  262.903568
# 4      5  216821.0  262.709474  2152.215291  216799.0  262.696146
# ..   ...       ...         ...          ...       ...         ...
# 250  251     364.0   10.764051    89.254833     359.0   10.689867
# 251  252     335.0   10.326365    86.769552     330.5   10.256774
# 252  253     294.0    9.673836    78.769552     293.0    9.657370
# 253  254     251.0    8.938444    73.112698     251.0    8.938444
# 254  255       0.0    0.000000     0.000000       0.0    0.000000
#
#      cntPerimeter  cntCircularity  cntIntensity   cntIntDen   hllArea  \
# 0     2133.102593        0.777146      17369187   79.425598  226014.5
# ...

# %%
df.to_csv ("/home/malkusch/PowerFolders/pharmacology/Daten/ristow/dataframe.csv", index = None, header = True)

# %% [markdown]
# ## Filter Data
# needs to be event driven

# %%
df = df[df['contours'] > 0]

# %% [markdown]
# ### ROI Area vs Threshod

# %%
df.plot(kind='scatter',x='thr',y='cntArea',color='red')
plt.show()

# %% [markdown]
# ### ROI Radius vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='cntRadius',color='red')
plt.show()

# %% [markdown]
# ### ROI Perimeter vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='cntPerimeter',color='red')
plt.show()

# %% [markdown]
# ### ROI Circularity vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='cntCircularity',color='red')
plt.show()

# %% [markdown]
# ### ROI Inntegrated Intensity vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='cntIntensity',color='red')
plt.show()

# %% [markdown]
# ### ROI Intensity Density vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='cntIntDen',color='red')
plt.show()

# %% [markdown]
# ### Hull Area vd Threshold

# %%
df.plot(kind='scatter',x='thr',y='hllArea',color='red')
plt.show()

# %% [markdown]
# ### Hull Radius vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='hllRadius',color='red')
plt.show()

# %% [markdown]
# ### Hull Perimeter vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='hllPerimeter',color='red')
plt.show()

# %% [markdown]
# ### Hull Circularity vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='hllCircularity',color='red')
plt.show()

# %% [markdown]
# ### Hull Integrated Intensity vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='hllIntensity',color='red')
plt.show()

# %% [markdown]
# ### Hull Integrated Density vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='hllIntDen',color='red')
plt.show()

# %% [markdown]
# ### Solidity vs Threshold

# %%
df.plot(kind='scatter',x='thr',y='solidity',color='red')
plt.show()
